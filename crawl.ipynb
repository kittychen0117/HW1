# %%
import requests
import csv
import urllib
from bs4 import BeautifulSoup

ETF_List = []
Adj_Close = {}
Date_List = []
### read file1
c1 = open("Healthcare Equity ETF List (49).csv", "r")
reader1 = csv.reader(c1)
for line in reader1:
    if line[0] != "Symbol":
        ETF_List.append(line[0])
        Adj_Close[line[0]] = []

        
c1.close()

c2 = open("Utilities Equity ETF List (24).csv", "r") ## read file2
reader2 = csv.reader(c2)
for line in reader2:
    if line[0] != "Symbol":
        ETF_List.append(line[0])
        Adj_Close[line[0]] = []
    
c2.close()

ETF_List  #All the ETF
# Out:
# ['XLV',
#  'IYH',
#  'IBB',
#  'IXJ',
#  'VHT',
#  'PJP',
#  'PBE',
#  'XBI',
#  'IHI',
#  'IHF',
#  'IHE',
#  'XPH',
#  'FBT',
#  'PTH',
#  'RYH',
#  'RXL',
#  'RXD',
#  'FXH',
#  'PSCH',
#  'BIB',
#  'BIS',
#  'XHE',
#  'CURE',
#  'XHS',
#  'BBH',
#  'PPH',
#  'FHLC',
#  'ARKG',
#  'BBP',
#  'BBC',
#  'SBIO',
#  'LABU',
#  'LABD',
#  'UBIO',
#  'ZBIO',
#  'JHMH',
#  'CNCR',
#  'XLU',
#  'IDU',
#  'VPU',
#  'PUI',
#  'JXI',
#  'RYU',
#  'UPW',
#  'SDP',
#  'GII',
#  'FXU',
#  'IGF',
#  'PXR',
#  'EMIF',
#  'PSCU',
#  'INXX',
#  'FUTY',
#  'TOLZ',
#  'WBIC',
#  'GHII',
#  'UTES']

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
import datetime
import time
import requests

# %%
yahoo_url = "https://finance.yahoo.com/quote/{}/history?period1={}&period2={}&interval=1d&filter=history&frequency=1d"
site = "https://query1.finance.yahoo.com/v7/finance/download/{}?period1={}&period2={}&interval=1d&events=history&crumb=pVo323aD3D1"

# %%
def get_timestamp():  # get now timestamp and 3 years age
    
    nowtime = datetime.datetime.now().date().timetuple()
    nowyear, nowmonth, nowday = datetime.datetime.now().strftime("%Y-%m-%d").split('-')
    threeyeartoday = datetime.datetime.strptime("{}-{}-{}".format(str(int(nowyear)-3), nowmonth, nowday), "%Y-%m-%d")
    threeyeartoday = threeyeartoday.timetuple()
    return  time.mktime(nowtime),  time.mktime(threeyeartoday)

now, past = get_timestamp()
now, past
# Out:
# (1552924800.0, 1458316800.0)

# %%
# driver = webdriver.Chrome()
# driver.set_window_size(1024,768)


for ETF in ETF_List:

    search_url = site.format(ETF, str(past)[0:len(str(past))-2], str(now)[0:len(str(now))-2])
    print(search_url)

    r = requests.post(search_url)
#     print(r.text.split('\n'))
    rows = r.text.split('\n')
    for idx, row in enumerate(rows):

        if idx == 0:
            continue
        else:
#             print(row)
            try:
                row = row.split(',')
#                 print(ETF, row[0])
                if ETF == ETF_List[0]:
                    Date_List.append(row[0])
                    Adj_Close[ETF].append((row[0], row[5]))
                else:
                    if Date_List[idx-1]!=row[0]:
                        Adj_Close[ETF].append((Date_List[idx-1], -1))
#                     print(Date_List[idx-1], row[0])
                    Adj_Close[ETF].append((row[0], row[5]))
                                           
            except:
                pass
#     print(len(Adj_Close[ETF]))
#     print(ETF, "Done!")
#     break
#     print(Date_List)
# Out:
# https://query1.finance.yahoo.com/v7/finance/download/XLV?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/IYH?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/IBB?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/IXJ?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/VHT?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/PJP?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/PBE?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/XBI?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/IHI?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/IHF?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/IHE?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/XPH?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/FBT?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/PTH?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/RYH?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/RXL?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/RXD?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/FXH?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/PSCH?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/BIB?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/BIS?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/XHE?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/CURE?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/XHS?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/BBH?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/PPH?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/FHLC?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/ARKG?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/BBP?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/BBC?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1
# https://query1.finance.yahoo.com/v7/finance/download/SBIO?period1=1458316800&period2=1552924800&interval=1d&events=history&crumb=pVo323aD3D1

# %%
import pandas as pd
df = pd.DataFrame()

# %%
list1 = [d[0] for d in Adj_Close['XLV']]
# print(list1)
for key, value in Adj_Close.items():
    list2 = [d[0] for d in value]
    diff_date = [d for d in list1 if d not in list2]
#     print(diff_date)
    if len(diff_date) > 0:
        for _date in diff_date:
            Adj_Close[key].append((_date, -1))
        print(key)
#     break

            
for key, value in Adj_Close.items():
    if len(value)!=len(list1):
        for i in range(len(value)-len(list1)):
            Adj_Close[key].pop()
# Out:
# PXR

# %%
for key, value in Adj_Close.items():
    print(key, len(value))
# Out:
# XLV 754
# IYH 754
# IBB 754
# IXJ 754
# VHT 754
# PJP 754
# PBE 754
# XBI 754
# IHI 754
# IHF 754
# IHE 754
# XPH 754
# FBT 754
# PTH 754
# RYH 754
# RXL 754
# RXD 754
# FXH 754
# PSCH 754
# BIB 754
# BIS 754
# XHE 754
# CURE 754
# XHS 754
# BBH 754
# PPH 754
# FHLC 754
# ARKG 754
# BBP 754
# BBC 754
# SBIO 754
# LABU 754
# LABD 754
# UBIO 754
# ZBIO 754
# JHMH 754
# CNCR 754
# XLU 754
# IDU 754
# VPU 754
# PUI 754
# JXI 754
# RYU 754
# UPW 754
# SDP 754
# GII 754
# FXU 754
# IGF 754
# PXR 754
# EMIF 754
# PSCU 754
# INXX 754
# FUTY 754
# TOLZ 754
# WBIC 754
# GHII 754
# UTES 754

# %%
df = pd.DataFrame(Adj_Close)

# %%
Adj_Clean = {}
for key, value in Adj_Close.items():
    Adj_Clean[key] = [d[1] for d in value]

# %%
df = pd.DataFrame(Adj_Clean)

# %%
df = df.T

Date_List.pop()
df.columns = Date_List
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-208-0abaa5cce549> in <module>()
#       2
#       3 Date_List.pop()
# ----> 4 df.columns = Date_List
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    3321             raise ValueError(
#    3322                 'Length mismatch: Expected axis has {old} elements, new '
# -> 3323                 'values have {new} elements'.format(old=old_len, new=new_len))
#    3324
#    3325         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 57 elements, new values have 754 elements

# %%
df.T
# Out:
#               0            1            2            3            4    \
# XLV     63.780811    64.152985    64.792320    64.334282    64.305649
# IYH    132.670654   133.494156   134.901764   133.876648   133.732635
# IBB     83.225243    84.930542    87.119286    84.241119    84.645317
# IXJ     45.030643    45.319973    45.670956    45.414829    45.324707
# VHT    116.687859   117.338600   118.667084   117.598526   117.473381
# PJP     56.804356    57.379421    59.192326    58.042198    57.886250
# PBE     36.467617    37.002304    38.289509    36.626041    36.883484
# XBI     49.330814    50.503223    52.162487    49.549408    49.728241
# IHI    118.560669   118.274086   118.946098   118.368355   117.864143
# IHF    115.060043   114.591164   115.308838   115.094086   114.586708
# IHE    128.986008   130.387711   133.587494   131.366882   131.357193
# XPH     37.586681    38.048294    39.600071    38.873291    38.686680
# FBT     83.940002    85.260002    87.570000    84.470001    85.089996
# PTH     41.279999    41.720001    42.610001    41.520000    41.759998
# RYH    140.066910   140.520950   142.040924   140.846664   140.372879
# RXL     55.067474    55.733692    57.135738    56.186825    56.017647
# RXD     54.093918    53.644798    52.726601    52.726601    52.726601
# FXH     54.139999    54.240002    55.110001    54.680000    54.610001
# PSCH    63.891300    63.751343    64.351166    63.241489    62.971569
# BIB     38.060001    39.599998    41.650002    38.869999    39.330002
# BIS     47.199085    45.365723    43.034168    45.814098    45.335835
# XHE     40.778927    40.798729    40.897701    40.699745    40.699745
# CURE    25.927673    26.304445    27.028238    26.512659    26.413509
# XHS     53.595024    53.327095    53.634712    53.525555    53.227863
# BBH     98.838593   100.624535   102.805161   100.032501   100.733070
# PPH     53.461361    53.790668    54.421066    54.054123    53.837708
# FHLC    29.916536    30.078348    30.430536    30.144978    30.106903
# ARKG    16.397820    16.630001    16.833160    16.494562    16.494562
# BBP     23.477474    23.936642    24.595448    23.746986    23.776930
# BBC     17.834494    18.323137    18.833542    17.577312    17.687109
# SBIO    19.715080    20.088760    21.025343    19.964516    19.935848
# LABU    24.646448    26.514811    29.098711    24.606697    24.924717
# LABD  6183.249512  5722.847168  5173.334961  5911.958496  5873.344238
# UBIO    21.430000    22.790001    24.440001    22.049999    22.360001
# ZBIO    82.705399    77.726280    71.687340    78.586128    77.526314
# JHMH    23.396990    23.980696    24.088861    24.098606    24.030394
# CNCR    20.409481    20.981068    21.542795    20.350353    20.319803
# XLU     43.991741    43.946514    43.801769    44.127434    44.245037
# IDU    112.106308   111.959427   111.628937   112.261536   112.686951
# VPU     96.391525    96.251495    96.004387    96.526062    96.892136
# PUI     23.012894    22.948277    22.929817    23.059048    23.114439
# JXI     43.132038    42.968456    42.877571    42.804863    42.886654
# RYU     74.640862    74.594925    74.337769    74.852089    75.201096
# UPW     36.387981    36.200031    36.206295    36.790512    36.876297
# SDP     36.823143    36.513283    36.593250    36.863125    36.003517
# GII     40.167778    40.095127    39.958900    39.559315    39.577477
# FXU     23.805820    23.749870    23.731222    23.744434    23.856878
# IGF     35.699512    35.597881    35.533207    35.209846    35.394627
# PXR     27.178028    27.197050    27.349203    27.349203    26.521879
# EMIF    27.351471    27.417173    27.342085    26.769526    26.769526
# PSCU    39.386551    39.395527    39.278744    39.260773    39.431469
# INXX     9.508648     9.670295     9.613242     9.594226     9.565701
# FUTY    28.322086    28.267551    28.194839    28.394800    28.467512
# TOLZ    34.088657    33.762009    33.997917    33.565369    33.537952
# WBIC    19.824898    19.800945    19.791355    19.753017    19.685928
# GHII    20.140955    20.140955    20.140955    20.140955    19.301031
# UTES    27.368637    27.267138    27.220999    27.202541    27.313274
#
#               5            6            7            8            9    \
# XLV     64.124352    64.868652    64.878197    64.677803    65.412575
# IYH    133.319794   134.971191   134.855942   134.942352   136.737747
# IBB     83.518837    85.019707    84.466408    86.411247    88.896141
# IXJ     45.234596    45.780048    45.756329    45.675697    45.965023
# VHT    117.194206   118.695946   118.763344   118.695946   120.284348
# PJP     57.252712    58.851189    58.451580    58.558784    59.728401
# PBE     36.190372    36.923088    36.705254    37.903347    38.873703
# XBI     49.082424    50.254833    49.847469    51.327892    52.818249
# IHI    118.101410   120.543312   120.938766   121.087074   122.362389
# IHF    114.701569   116.960945   117.171570   116.779053   117.726845
# IHE    129.613266   132.665131   132.248535   132.713577   134.825699
# XPH     38.048294    39.334892    39.128643    39.521511    40.209007
# FBT     83.739998    85.290001    84.910004    87.559998    89.910004
# PTH     41.630001    43.099998    42.959999    43.299999    43.939999
# RYH    140.047180   142.455490   142.494965   142.435760   144.301208
# RXL     55.579769    57.132221    57.132221    56.923244    58.525455
# RXD     52.726601    52.726601    52.287460    52.387264    50.999985
# FXH     54.380001    55.459999    55.480000    55.740002    56.389999
# PSCH    62.901588    65.580811    65.680771    66.220619    67.130348
# BIB     38.320000    39.669998    39.200001    40.880001    43.230000
# BIS     46.551430    44.777851    45.405579    43.402832    40.981598
# XHE     40.491894    41.669731    41.996361    42.105232    41.917171
# CURE    26.195379    27.127388    27.097643    26.909258    27.910671
# XHS     53.237789    54.676647    54.934647    54.954502    55.371273
# BBH     99.716751   100.427177    99.736496   102.301933   104.818047
# PPH     53.498993    54.289337    54.251705    54.101162    54.640537
# FHLC    30.021240    30.440050    30.421015    30.440050    30.858864
# ARKG    16.223686    16.446190    16.929903    16.973436    17.258827
# BBP     23.417582    23.896715    23.946623    24.615412    24.994726
# BBC     17.548626    18.597134    18.329073    18.843433    19.340979
# SBIO    19.802050    20.528378    20.432808    20.948885    21.636988
# LABU    23.960724    25.590569    24.974405    27.250229    29.784437
# LABD  6102.060547  5643.638184  5799.085938  5264.425293  4806.003418
# UBIO    21.469999    22.620001    22.240000    23.680000    25.760000
# ZBIO    80.605774    76.266533    77.626297    72.447212    66.328285
# JHMH    23.962179    24.303247    24.381205    24.361713    24.644310
# CNCR    20.350353    20.577015    20.915037    21.385117    21.927135
# XLU     44.082203    44.733528    44.624973    44.887318    45.059196
# IDU    112.381775   114.148148   113.861450   114.379333   114.943459
# VPU     96.635880    98.219177    97.944618    98.411377    98.859810
# PUI     23.040583    23.465216    23.400597    23.428289    23.511366
# JXI     43.122952    43.559181    43.713673    43.677322    43.695503
# RYU     75.109238    76.156258    76.055244    76.450172    76.542000
# UPW     36.634823    37.505413    37.816795    38.064629    38.464973
# SDP     36.723190    35.133919    35.293842    35.053951    35.053951
# GII     39.768188    40.385735    40.612778    40.867058    40.113285
# FXU     23.847511    24.287914    24.231693    24.344135    24.456581
# IGF     35.283756    35.819618    36.069073    36.115265    35.902771
# PXR     26.702560    26.835691    27.444296    27.634485    27.567919
# EMIF    26.966635    26.919704    27.755079    27.736305    27.802011
# PSCU    39.440460    40.410744    40.437698    40.392773    40.707222
# INXX     9.508648     9.575209     9.736856     9.784398     9.803416
# FUTY    28.385708    28.867441    28.785637    28.931067    29.076490
# TOLZ    33.556232    33.812111    34.296444    34.378685    34.049706
# WBIC    19.757807    19.915949    19.954277    19.915949    19.915949
# GHII    19.301031    19.301031         null    19.301031    19.309603
# UTES    27.220999    27.387093    27.539345    27.663916    27.793104
#
#          ...             744         745         746         747         748  \
# XLV      ...       91.300003   89.964973   89.257607   89.068314   90.084526
# IYH      ...      193.360001  190.320007  188.830002  188.429993  190.779999
# IBB      ...      113.419998  109.870003  109.139999  108.610001  110.930000
# IXJ      ...       60.889999   60.209999   59.590000   59.610001   60.099998
# VHT      ...      172.899994  169.869995  168.699997  168.350006  170.610001
# PJP      ...       67.389999   65.669998   65.330002   65.150002   65.820000
# PBE      ...       55.410000   53.720001   53.450001   53.169998   54.500000
# XBI      ...       90.220001   86.529999   86.559998   86.459999   89.040001
# IHI      ...      227.360001  224.089996  222.830002  222.330002  225.350006
# IHF      ...      171.360001  166.699997  165.250000  165.830002  167.869995
# IHE      ...      156.000000  152.119995  151.389999  150.779999  151.860001
# XPH      ...       42.470001   41.060001   40.980000   40.959999   41.200001
# FBT      ...      148.729996  144.529999  143.699997  143.050003  146.350006
# PTH      ...       80.250000   78.150002   78.309998   78.400002   79.940002
# RYH      ...      196.610001  192.610001  191.350006  191.000000  193.470001
# RXL      ...      104.180000  100.959999   99.269997   98.870003  101.190002
# RXD      ...       22.260000   23.000000   23.450001   23.520000   22.959999
# FXH      ...       76.040001   74.349998   74.019997   74.019997   75.089996
# PSCH     ...      118.720001  114.669998  114.830002  115.019997  117.080002
# BIB      ...       57.500000   53.810001   53.049999   52.560001   54.770000
# BIS      ...       16.420000   17.430000   17.660000   17.850000   17.100000
# XHE      ...       80.860001   79.120003   78.860001   78.550003   79.519997
# CURE     ...       55.430000   52.889999   51.630001   51.240002   53.080002
# XHS      ...       66.470001   64.300003   63.919998   63.990002   64.940002
# BBH      ...      129.740005  126.209999  125.370003  124.849998  127.580002
# PPH      ...       60.669998   59.610001   59.290001   59.040001   59.459999
# FHLC     ...       44.351460   43.584206   43.255379   43.185631   43.733669
# ARKG     ...       31.680000   30.450001   30.510000   30.580000   31.780001
# BBP      ...       45.200001   43.411999   43.320000   43.154999   44.230000
# BBC      ...       27.600000   26.289000   26.479000   26.462000   27.139999
# SBIO     ...       35.860001   34.119999   34.250000   34.189999   35.189999
# LABU     ...       60.860001   53.430000   53.380001   53.200001   58.000000
# LABD     ...       19.389999   21.770000   21.790001   21.850000   19.889999
# UBIO     ...       31.100000   28.190001   27.620001   27.239000   29.000000
# ZBIO     ...       12.940000   14.130000   14.430000   14.700000   13.860000
# JHMH     ...       34.054001   33.419998   33.160999   33.087002   33.529999
# CNCR     ...       21.879999   20.945000   20.680000   20.372999   20.780001
# XLU      ...       56.739201   56.739201   56.927799   57.126328   57.533310
# IDU      ...      144.820007  144.779999  145.210007  145.779999  146.830002
# VPU      ...      127.290001  127.209999  127.650002  128.160004  129.119995
# PUI      ...       31.549999   31.530001   31.629999   31.799999   32.160000
# JXI      ...       52.869999   52.740002   53.009998   53.180000   53.500000
# RYU      ...       94.940002   94.919998   95.089996   95.500000   96.330002
# UPW      ...       54.830002   54.820000   54.880001   55.419998   56.259998
# SDP      ...       19.540001   19.540001   19.490000   19.340000   18.980000
# GII      ...       50.220001   50.209999   50.080002   50.209999   50.599998
# FXU      ...       28.160000   28.020000   28.170000   28.200001   28.459999
# IGF      ...       43.700001   43.779999   43.660000   43.770000   44.080002
# PXR      ...              -1          -1          -1          -1          -1
# EMIF     ...       29.360001   29.350000   28.719999   28.719999   29.219999
# PSCU     ...       53.450001   52.790001   53.000000   52.950001   53.619999
# INXX     ...       11.250000   11.430000   11.290000   11.370000   11.820000
# FUTY     ...       37.354958   37.345032   37.454170   37.612919   37.900646
# TOLZ     ...       42.880001   42.830002   42.880001   42.919998   43.419998
# WBIC     ...       20.827204   20.638626   20.329323   20.279436   20.472998
# GHII     ...       26.309999   26.180000   26.162001   26.035000   26.325001
# UTES     ...       36.437000   36.450001   36.547001   36.744999   36.900002
#
#              749         750         751         752         753
# XLV    90.742081   91.718445   91.569000   91.989998   91.625000
# IYH   192.160004  194.279999  193.919998  194.970001  194.259995
# IBB   111.839996  113.300003  112.989998  114.199997  113.614998
# IXJ    60.400002   61.090000   60.950001   61.349998   61.189899
# VHT   171.899994  173.740005  173.350006  174.300003  173.615005
# PJP    65.959999   66.180000   65.919998   66.250000   66.192703
# PBE    55.000000   55.619999   55.169998   55.689999   55.484901
# XBI    89.970001   91.690002   90.570000   91.269997   91.223701
# IHI   226.889999  228.550003  228.750000  230.649994  227.710007
# IHF   169.830002  173.360001  173.509995  172.350006  173.566101
# IHE   152.889999  154.130005  152.910004  153.119995  153.679993
# XPH    41.509998   41.959999   41.730000   41.750000   41.820099
# FBT   147.479996  150.589996  149.619995  151.460007  150.528000
# PTH    80.760002   81.809998   81.800003   81.480003   80.840202
# RYH   195.059998  197.429993  197.050003  198.270004  197.097595
# RXL   102.540001  104.919998  104.489998  105.389999  104.629997
# RXD    22.549999   22.090000   22.059999   21.930000   22.070000
# FXH    75.660004   76.660004   76.680000   76.980003   76.719002
# PSCH  117.680000  117.949997  117.419998  117.519997  117.599998
# BIB    55.680000   57.240002   56.730000   58.000000   57.349998
# BIS    16.830000   16.389999   16.490000   16.129999   16.309999
# XHE    79.900002   80.190002   79.839996   80.660004   79.740501
# CURE   54.220001   55.930000   55.639999   56.349998   55.730000
# XHS    65.620003   66.739998   66.739998   66.129997   66.324699
# BBH   128.740005  130.419998  130.169998  131.339996  129.970001
# PPH    59.580002   60.200001   60.130001   60.549999   60.699902
# FHLC   44.072460   44.560715   44.480999   44.680000   44.513199
# ARKG   32.130001   32.490002   32.169998   32.790001   32.580002
# BBP    44.716999   45.570999   45.074001   45.313000   45.520000
# BBC    27.628000   28.141001   27.893000   28.107000   28.680000
# SBIO   35.520000   36.049999   35.689999   35.919998   36.090000
# LABU   59.750000   63.119999   60.750000   62.259998   62.160000
# LABD   19.270000   18.190001   18.879999   18.400000   18.449800
# UBIO   29.570000   30.790001   30.410000   31.459999   30.900000
# ZBIO   13.360000   12.936000   13.020000   12.580000   12.770000
# JHMH   33.772999   34.200001   34.148998   34.300999   34.177399
# CNCR   21.004999   21.280001   21.122999   21.389999   21.316500
# XLU    57.930367   57.989925   57.980000   58.189999   57.882900
# IDU   147.789993  148.009995  147.820007  148.449997  147.669998
# VPU   129.899994  129.990005  129.839996  130.419998  129.850006
# PUI    32.320000   32.349998   32.250000   32.419998   32.240002
# JXI    53.889999   53.900002   53.820000   54.150002   54.093102
# RYU    97.050003   97.250000   97.059998   97.529999   96.320000
# UPW    56.880001   57.110001   57.029999   57.410000   56.895699
# SDP    18.840000   18.820000   18.809999   18.670000          -1
# GII    50.680000   50.860001   50.830002   51.119999   51.209999
# FXU    28.590000   28.620001   28.600000   28.780001   28.705999
# IGF    44.209999   44.310001   44.330002   44.590000   44.660099
# PXR           -1          -1          -1          -1          -1
# EMIF   29.340000   29.240000   29.250000   29.559999   29.490000
# PSCU   53.750000   54.020000   53.770000   53.980000   53.907501
# INXX   11.890000   11.830000   11.850000   11.960000   12.030800
# FUTY   38.138763   38.168530   38.108997   38.290001   38.103298
# TOLZ   43.540001   43.740002   43.770000   43.849998   43.903301
# WBIC   20.450001   20.530001   20.500000   20.542000   20.591999
# GHII   26.400000   26.549999   26.570999   26.587999   26.353201
# UTES   37.153999   37.247002   37.162998   37.258999          -1
#
# [57 rows x 754 columns]
